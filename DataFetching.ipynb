# %%
#!pip install --target=/opt/anaconda3/lib/python3.7/site-packages nest_asyncio
#!pip3 install --target=/opt/anaconda3/lib/python3.7/site-packages git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /private/var/folders/x9/b6zg3l_945vbq6g3sdx4xcyc0000gn/T/pip-install-pn1uoegv/twint_13bfb72963124646a2d292739d89cdb9
#   Running command git clone -q https://github.com/twintproject/twint.git /private/var/folders/x9/b6zg3l_945vbq6g3sdx4xcyc0000gn/T/pip-install-pn1uoegv/twint_13bfb72963124646a2d292739d89cdb9
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
# ...
#   Using cached aiohttp-3.7.4.post0-cp38-cp38-macosx_10_14_x86_64.whl (648 kB)
# ...
#   Using cached aiodns-2.0.0-py2.py3-none-any.whl (4.8 kB)
# ...
#   Using cached beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# ...
#   Using cached cchardet-2.1.7-cp38-cp38-macosx_10_9_x86_64.whl (124 kB)
# ...
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# ...
#   Using cached elasticsearch-7.12.1-py2.py3-none-any.whl (339 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# ...

# %%
import nest_asyncio
import pandas as pd
import twint
nest_asyncio.apply()

# Data fetching main function
def scrape_by_keyword(keywords, since='2021-03-01', until='2021-04-01', limit=100, city=''):
    # initiate data frame
    df = pd.DataFrame()

    # loop through all keywords and append result
    for word in keywords:
      # setup twint
      c = twint.Config()
      # configurations
      c.Limit = limit   # increments of 20
      c.Search = word
      c.Since = since
      c.Until = until
      c.Near = city

      c.Pandas = True
      c.Stats = True
      c.Lower_case = True
      c.Hide_output = False
      # run twint
      twint.run.Search(c)

      # store data frame
      Tweets_df = twint.storage.panda.Tweets_df
      # append to result data frame
      df = df.append(Tweets_df)

    return df

# %%
#scrape_by_keyword('Elon Musk')
# Out:
# 1377047990888697858 2021-03-30 16:59:59 -0700 <impIutao> medo de fazer enem e zerar | 1 replies 2 retweets 7 likes
# 1377047990834184193 2021-03-30 16:59:59 -0700 <jimincIassic> professor filho da puta fez as perguntas tudo diferente e eu nao sei nada de penal me fodiiiiiiii | 0 replies 0 retweets 0 likes
# 1377047990813216769 2021-03-30 16:59:59 -0700 <Yukaa_> Uma parte da biografia da Gwen é uma descrição muito básica de A Bela e a Fera. Além de certa parte também lembra um pouquinho de Cinderela.  Gwen, Isolde e Viego são todos trabalhados no conceito de contos de fada. Adorei demais isso | 0 replies 0 retweets 0 likes
# 1377047990809018369 2021-03-30 16:59:59 -0700 <kuyjey> @ShopeeID E. NCT 127 #BelanjadiShopee44 #MakinSayangShopee #ShopeediHati   E. NCT 127 #BelanjadiShopee44 #MakinSayangShopee #ShopeediHati   E. NCT 127 #BelanjadiShopee44 #MakinSayangShopee #ShopeediHati   E. NCT 127 #BelanjadiShopee44 #MakinSayangShopee #ShopeediHati   13.202 | 0 replies 0 retweets 0 likes
# ...
